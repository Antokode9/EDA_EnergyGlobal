# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
#titulo = "El impacto del conflicto Rusia Ucrania en el escenario energético"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
#tema = "El conflicto Rusia Ucrania ha tenido un impacto contundente en Europa y a nivel global, encareciendo la gran mayoría de las materias primas. Uno de los sectores más vulnerables es el energético con el aumento de precios y la volatilidad del mercado energético. Aunque los gobiernos de los países europeos han tomado medidas de mitigación para enfrentar la fluctuación de los precios; dando una respuesta global al problema; sin embargo, es muy interesante comprender cuál ha sido la respuesta de los consumidores al desafío, en especial de la propaganda por mejora de las tarifas, cambios en el patrón de consumo y la adquisición de dispositivos y controladores inteligentes que ayuden a ahorrar energía y disminuir la factura energética.  "

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
#hipotesis_1 = "El patrón de consumo energético ha cambiado como consecuencia del conflicto Rusia Ucrania"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = "Los precios de la energía han aumentado"
# hipotesis_3 = "Los consumidores han cambiado de compañía"
# hipotesis_4 = "Han incrementado las ventas de dispositivos de control inteligente de consumo energético"
# hipotesis_5 = "Hay más interés en energías renovables y el cambio climático"
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # Data_Preparation

# %%
#shape
#head
#columns
#dtypes
#describe

# %%
df1 = pd.read_csv('WEO2022_AnnexA_Free_Dataset_World.csv')
df1.shape
# Out:
# (3222, 9)

# %%
df1.head(10)
# Out:
#                  PUBLICATION                  SCENARIO CATEGORY     PRODUCT  \
# 0  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 1  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 2  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 3  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 4  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 5  World Energy Outlook 2022  Stated Policies Scenario   Energy       Total
# 6  World Energy Outlook 2022  Stated Policies Scenario   Energy  Renewables
# 7  World Energy Outlook 2022  Stated Policies Scenario   Energy  Renewables
# 8  World Energy Outlook 2022  Stated Policies Scenario   Energy  Renewables
# 9  World Energy Outlook 2022  Stated Policies Scenario   Energy  Renewables
#
#                   FLOW UNIT REGION  YEAR    VALUE
# 0  Total energy supply   EJ  World  2010  541.981
# ...

# %%
df1.tail(10)
# Out:
#                     PUBLICATION                             SCENARIO  \
# 3212  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3213  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3214  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3215  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3216  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3217  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3218  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3219  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3220  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
# 3221  World Energy Outlook 2022  Net Zero Emissions by 2050 Scenario
#
#                 CATEGORY PRODUCT                 FLOW    UNIT REGION  YEAR  \
# 3212   CO2 total removed   Total  Total energy supply  Mt CO2  World  2021
# ...

# %%
df1.columns
# Out:
# Index(['PUBLICATION', 'SCENARIO', 'CATEGORY', 'PRODUCT', 'FLOW', 'UNIT',
#        'REGION', 'YEAR', 'VALUE'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# PUBLICATION     object
# SCENARIO        object
# CATEGORY        object
# PRODUCT         object
# FLOW            object
# UNIT            object
# REGION          object
# YEAR             int64
# VALUE          float64
# dtype: object

# %%
df1.describe()
# Out:
#               YEAR         VALUE
# count  3222.000000   3222.000000
# mean   2028.500000   1796.720442
# std      13.340611   5551.027921
# min    2010.000000   -731.460000
# 25%    2020.000000      5.143750
# 50%    2025.500000     40.194500
# 75%    2040.000000    547.435000
# max    2050.000000  73231.400000

# %% [markdown]
# # Data_Understanding

# %%
df1.columns
# Out:
# Index(['PUBLICATION', 'SCENARIO', 'CATEGORY', 'PRODUCT', 'FLOW', 'UNIT',
#        'REGION', 'YEAR', 'VALUE'],
#       dtype='object')

# %% [markdown]
# # Eliminando columnas que no parecen necesarias y guardandno una copia del nuevo df.

# %%
df1_1 = df1.drop(["PUBLICATION", "REGION"], axis = 1).copy()

# %%
df1_1
# Out:
#                                  SCENARIO            CATEGORY PRODUCT  \
# 0                Stated Policies Scenario              Energy   Total
# 1                Stated Policies Scenario              Energy   Total
# 2                Stated Policies Scenario              Energy   Total
# 3                Stated Policies Scenario              Energy   Total
# 4                Stated Policies Scenario              Energy   Total
# ...                                   ...                 ...     ...
# 3217  Net Zero Emissions by 2050 Scenario  CO2 total captured   Total
# 3218  Net Zero Emissions by 2050 Scenario  CO2 total captured   Total
# 3219  Net Zero Emissions by 2050 Scenario  CO2 total captured   Total
# 3220  Net Zero Emissions by 2050 Scenario  CO2 total captured   Total
# 3221  Net Zero Emissions by 2050 Scenario  CO2 total captured   Total
#
#                      FLOW    UNIT  YEAR     VALUE
# 0     Total energy supply      EJ  2010   541.981
# ...

# %% [markdown]
# # Data_Cleaning and Analysis

# %%
df1_1["CATEGORY"].value_counts()
# Out:
# Energy                        2232
# CO2 combustion                 414
# Capacity: installed            360
# CO2 combustion and process     108
# CO2 total removed               36
# CO2 total                       18
# CO2 process stored              18
# CO2 DAC                         18
# CO2 total captured              18
# Name: CATEGORY, dtype: int64

# %%
df1_1["CATEGORY"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df1_1["UNIT"].value_counts().plot(kind = "pie", title="Tipo de energía consumida")
# Out:
# <AxesSubplot:title={'center':'Tipo de energía consumida'}, ylabel='UNIT'>

# %% [markdown]
# # Data sobre patentes relacionadas con  energía

# %% [markdown]
# # Data_preparation
# #shape
# #head
# #columns
# #dtypes
# #describe

# %%
df2 = pd.read_csv('IEA_h2020_data_topic_Patents.csv')
df2.shape
# Out:
# (18881, 10)

# %%
df2.head(10)
# Out:
#           country countryISO  \
# 0     Netherlands        NLD
# 1   United States        USA
# 2          France        FRA
# 3           Japan        JPN
# 4       Australia        AUS
# 5  Czech Republic        CZE
# 6           Korea        KOR
# 7   United States        USA
# 8   United States        USA
# 9         Belgium        BEL
#
#                                           techSector    topic indicator  \
# 0                           Hydrogen fuel production  Patents    Detail
# 1                                            Nuclear  Patents    Detail
# 2                                            Nuclear  Patents    Detail
# 3                                               Grid  Patents    Detail
# 4          Renewable energy integration in buildings  Patents    Detail
# 5                                Air - rail - marine  Patents    Detail
# 6                      Agriculture energy efficiency  Patents    Detail
# ...

# %%
df2.columns
# Out:
# Index(['country', 'countryISO', 'techSector', 'topic', 'indicator', 'category',
#        'unit', 'year', 'observations', 'value'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# country          object
# countryISO       object
# techSector       object
# topic            object
# indicator        object
# category         object
# unit             object
# year              int64
# observations      int64
# value           float64
# dtype: object

# %%
df2.describe()
# Out:
#                year  observations          value
# count  18881.000000       18881.0   18881.000000
# mean    2010.647370           0.0     685.412758
# std        5.990371           0.0    9625.111288
# min     2000.000000           0.0       0.050000
# 25%     2006.000000           0.0       2.000000
# 50%     2011.000000           0.0       7.000000
# 75%     2016.000000           0.0      33.090000
# max     2021.000000           0.0  359923.593750

# %% [markdown]
# # Data_cleaning and Analysis

# %%
df2["country"].value_counts()
# Out:
# United States                 851
# Japan                         787
# Germany                       747
# People's Republic of China    734
# Great Britain                 727
# United Kingdom                727
# Korea                         720
# France                        711
# Canada                        707
# Netherlands                   627
# Italy                         621
# Spain                         590
# Norway                        585
# Switzerland                   561
# Russian Federation            560
# Sweden                        552
# Finland                       550
# Austria                       545
# Chinese Taipei                529
# Denmark                       481
# Belgium                       472
# Australia                     469
# India                         435
# Brazil                        434
# Israel                        420
# Poland                        368
# Singapore                     368
# ...

# %%
df2["country"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df2["techSector"].value_counts().plot(kind = "bar", title="Tipo de patentes por sector tecnológico")
# Out:
# <AxesSubplot:title={'center':'Tipo de patentes por sector tecnológico'}>

# %%
df2.plot(kind = "scatter", x = "techSector", y = "value")
# Out:
# <AxesSubplot:xlabel='techSector', ylabel='value'>

# %% [markdown]
# # Data de venta y fabricación de vehículos eléctricos.

# %%
df3 = pd.read_csv('IEA-EV-data_23.csv')
df3.shape
# Out:
# (7434, 8)

# %%
df3.head(10)
# Out:
#       region    category       parameter  mode powertrain  year     unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011    sales
# 1  Australia  Historical        EV stock  Cars        BEV  2011    stock
# 2  Australia  Historical  EV stock share  Cars         EV  2011  percent
# 3  Australia  Historical  EV sales share  Cars         EV  2011  percent
# 4  Australia  Historical  EV sales share  Cars         EV  2012  percent
# 5  Australia  Historical  EV stock share  Cars         EV  2012  percent
# 6  Australia  Historical        EV stock  Cars        BEV  2012    stock
# 7  Australia  Historical        EV sales  Cars       PHEV  2012    sales
# 8  Australia  Historical        EV sales  Cars        BEV  2012    sales
# 9  Australia  Historical        EV stock  Cars       PHEV  2012    stock
#
#        value
# 0   49.00000
# 1   49.00000
# 2    0.00046
# 3    0.00650
# 4    0.03000
# 5    0.00280
# 6  220.00000
# 7   80.00000
# 8  170.00000
# 9   80.00000

# %%
df3.columns
# Out:
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# region         object
# category       object
# parameter      object
# mode           object
# powertrain     object
# year            int64
# unit           object
# value         float64
# dtype: object

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of          region          category              parameter    mode powertrain  \
# 0     Australia        Historical               EV sales    Cars        BEV
# 1     Australia        Historical               EV stock    Cars        BEV
# 2     Australia        Historical         EV stock share    Cars         EV
# 3     Australia        Historical         EV sales share    Cars         EV
# 4     Australia        Historical         EV sales share    Cars         EV
# ...         ...               ...                    ...     ...        ...
# 7429      World  Projection-STEPS   Oil displacement Mbd    Cars         EV
# 7430      World  Projection-STEPS  Oil displacement Mlge   Buses         EV
# 7431      World  Projection-STEPS  Oil displacement Mlge  Trucks         EV
# 7432      World  Projection-STEPS  Oil displacement Mlge    Vans         EV
# 7433      World  Projection-STEPS  Oil displacement Mlge    Cars         EV
#
# ...

# %%
df3["parameter"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df3["year"].value_counts().plot(kind = "bar", title="Ventas totales de EVs por año")
# Out:
# <AxesSubplot:title={'center':'Ventas totales de EVs por año'}>

# %%
# guarda en variables los datasets y su fuente
# df_1 = pd.DataFrame()
# fuente_1 = ""
# df_2 = pd.DataFrame()
# fuente_2 = ""
# df_3 = pd.DataFrame()
# fuente_3 = ""
# df_4 = pd.DataFrame()
# fuente_4 = ""
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
